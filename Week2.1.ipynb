# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statistics as stats
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df = pd. read_csv('Inflation by Month.csv')

# %%
df
# Out:
#      Year Month  Inflation
# 0    1989   JAN        5.7
# 1    1989   FEB        5.8
# 2    1989   MAR        5.9
# 3    1989   APR        5.6
# 4    1989   MAY        5.9
# ..    ...   ...        ...
# 410  2023   MAR        8.9
# 411  2023   APR        7.8
# 412  2023   MAY        7.9
# 413  2023   JUN        7.3
# 414  2023   JUL        6.4
#
# [415 rows x 3 columns]

# %% [markdown]
# W2.5. Which year and month has the highest inflation in UK inflation data 1989-2022?

# %%
max_inflation_row = df.loc[df['Inflation'].idxmax()]

# Display the result
print(f"Highest inflation was {max_inflation_row['Inflation']}% in {max_inflation_row['Month']} {int(max_inflation_row['Year'])}")
# Out:
# Highest inflation was 9.6% in OCT 2022

# %% [markdown]
# W2.6. Write a snippet of code using pandas in Jupyter notebook to count the number of times
# ChatGPT is repeated in this text:

# %%
import pandas as pd
import string

# Define the text
text = "ChatGPT is an artificial intelligence (AI) chatbot that uses natural language processing to create humanlike conversational dialogue. The language model can respond to questions and compose various written content, including articles, social media posts, essays, code and emails. ChatGPT, which stands for Chat Generative Pre-trained Transformer, is a large language model-based chatbot developed by OpenAI and launched on November 30, 2022, which enables users to refine and steer a conversation towards a desired length, format, style, level of detail, and language"

# %%
# Convert text to a pandas Series
words = [word.strip(string.punctuation) for word in text.split()]

# %%
# Count occurrences of 'ChatGPT'
text_series = pd.Series(words)

chatgpt_count = text_series[text_series == 'ChatGPT'].count()

print(f"'ChatGPT' appears {chatgpt_count} times in the text.")
# Out:
# 'ChatGPT' appears 2 times in the text.

# %%
print(f"'ChatGPT' appears {chatgpt_count} times in the text.")
# Out:
# 'ChatGPT' appears 2 times in the text.

# %%
words = text.split()

# Convert to pandas Series
text_series = pd.Series(words)

# Clean punctuation (optional for better matching)
text_series = text_series.str.strip(",.?!")

# Count occurrences of 'ChatGPT'
chatgpt_count = text_series[text_series == 'ChatGPT'].count()

print(f"'ChatGPT' appears {chatgpt_count} times in the text.")
# Out:
# 'ChatGPT' appears 2 times in the text.
